# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras.utils import plot_model
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.optimizers import SGD,Adam
from keras_radam.training import RAdamOptimizer
from tensorflow.keras.callbacks import LearningRateScheduler,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler

tf.compat.v1.disable_eager_execution()

from VAE_small import *

model_num = 14

learning_rate_1 = 0.0001
learning_rate_2 = 0.005
momentum = 0.9
batch_size = 4
epoch_num = 1000

# %%
#TF2.0
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(physical_devices[1], 'GPU')
tf.config.experimental.set_memory_growth(physical_devices[1], True)
# ------------------------------------------------------------------------------

# %%
model = get_model()

inputs = model['inputs']
outputs = model['outputs']
mu = model['mu']
sigma = model['sigma']
z = model['z']

encoder = model['encoder']
decoder = model['decoder']

#plot_model(encoder, to_file = 'vae_encoder_{}.png'.format(model_num), show_shapes = True)
#plot_model(decoder, to_file = 'vae_decoder_{}.png'.format(model_num), show_shapes = True)

vae = model['vae']
# Out:
# WARNING:tensorflow:From C:\Users\dl-box\.conda\envs\matsu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
def weighted_binary_crossentropy(target, output):
    loss = -(98.0 * target * K.log(output) + 2.0 * (1.0 - target) * K.log(1.0 - output)) / 100.0
    return loss

def mse(target, output):
    loss = K.square((output-target))
    return loss

def kl_div(mu,sigma):
    return -0.5 * K.mean(1 + 2 * sigma - K.square(mu) - K.exp(2 * sigma))

def voxel_loss(inputs,outputs):# = 
    return K.cast(K.mean(weighted_binary_crossentropy(inputs, K.clip(K.sigmoid(outputs), 1e-7, 1.0 - 1e-7))), 'float32')+ kl_div(model['mu'],model['sigma'])
#    return 0.01*K.cast(K.mean(mse(inputs, K.clip(K.sigmoid(outputs), 1e-7, 1.0 - 1e-7))), 'float32')+ kl_div(model['mu'],model['sigma'])
# K.clip(a,a_min,a_max) = make a in range a_min to a_max


def custom_acc(y_true, y_pred):
    return K.mean(K.equal(K.round(y_true*10), K.round(y_pred*10)))

sgd = SGD(lr = learning_rate_1, momentum = momentum, nesterov = True)
adam = Adam(lr=1e-3)
radam = RAdamOptimizer(learning_rate=1e-3)

# %%
vae.compile(optimizer = adam, metrics = ['accuracy',custom_acc], loss=voxel_loss)

plot_model(vae, to_file = 'vae_{}.png'.format(model_num), show_shapes = True, expand_nested = True)

# %%
vae.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 40, 40, 40)]   0
# _________________________________________________________________
# model (Model)                [(None, 50), (None, 50),  278884116
# _________________________________________________________________
# model_1 (Model)              (None, 2, 40, 40, 40)     21601820
# =================================================================
# Total params: 300,485,936
# Trainable params: 300,482,606
# Non-trainable params: 3,330
# _________________________________________________________________

# %%
def make_dataset(mol_name):
    data = []
    for i in range(50):
        data_0 = np.load('volume_fraction/{}_0/{}[{}].npy'.format(mol_name,mol_name,i+51))
        data.append(data_0)
    return data

# %%
data_cross = make_dataset('Cross')
data_diblock = make_dataset('Diblock')
data_dragonfly = make_dataset('Dragonfly')
data_hydrophilic = make_dataset('HydrophilicSideChain1')
data_triblock = make_dataset('Triblock')
data_tshape = make_dataset('T-shape')
data_cross[0].shape
# Out:
# (4, 80, 80, 80)

# %%
data_train = np.vstack((data_cross,data_diblock,data_dragonfly,data_hydrophilic,data_triblock,data_tshape))
data_train = data_train.reshape(-1,4,80,80,80)
data_train[:,1,:,:,:] = data_train[:,2,:,:,:]
data_train = data_train[:,:2,:,:,:]
data_train.shape
# Out:
# (300, 2, 80, 80, 80)

# %%
A_max = np.max(data_train[:,0,:,:,:])
B_max = np.max(data_train[:,1,:,:,:])
#C_max = np.max(data_train[:,2,:,:,:])
#W_max = np.max(data_train[:,3,:,:,:])

data_train[:,0,:,:,:] /= A_max
data_train[:,1,:,:,:] /= B_max
#data_train[:,2,:,:,:] /= C_max
#data_train[:,3,:,:,:] /= W_max

# %%
data_train = data_train[:,:,20:60,20:60,20:60]
data_train.shape
# Out:
# (300, 2, 40, 40, 40)

# %%
early_stopping = EarlyStopping(monitor='loss',min_delta=1e-8,patience=5,verbose=0,mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=3, min_lr=1e-7)

history = vae.fit(
    data_train,
    data_train,
    epochs = epoch_num,
    batch_size = batch_size,
#    validation_data = (data_train, None),
    callbacks = [reduce_lr,early_stopping]
)

vae.save_weights('vae_{}.h5'.format(model_num))
# Out:
# Train on 300 samples
# Epoch 1/1000
# 300/300 [==============================] - 31s 103ms/sample - loss: 2.5120 - accuracy: 0.0238 - custom_acc: 0.0301
# Epoch 2/1000
# 300/300 [==============================] - 24s 80ms/sample - loss: 1.4729 - accuracy: 0.0254 - custom_acc: 0.0393
# Epoch 3/1000
# 300/300 [==============================] - 24s 81ms/sample - loss: 1.1540 - accuracy: 0.0258 - custom_acc: 0.0238
# Epoch 4/1000
# 300/300 [==============================] - 24s 81ms/sample - loss: 0.9000 - accuracy: 0.0270 - custom_acc: 0.0224
# Epoch 5/1000
# 300/300 [==============================] - 24s 81ms/sample - loss: 0.7592 - accuracy: 0.0281 - custom_acc: 0.0213
# Epoch 6/1000
# 300/300 [==============================] - 24s 81ms/sample - loss: 0.7783 - accuracy: 0.0286 - custom_acc: 0.0215
# Epoch 7/1000
# 300/300 [==============================] - 24s 81ms/sample - loss: 0.6789 - accuracy: 0.0283 - custom_acc: 0.0196
# Epoch 8/1000
# 300/300 [==============================] - 24s 82ms/sample - loss: 0.5564 - accuracy: 0.0262 - custom_acc: 0.0216
# Epoch 9/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.4944 - accuracy: 0.0257 - custom_acc: 0.0242
# Epoch 10/1000
# 300/300 [==============================] - 24s 82ms/sample - loss: 0.4548 - accuracy: 0.0263 - custom_acc: 0.0239
# Epoch 11/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.4023 - accuracy: 0.0264 - custom_acc: 0.0293
# Epoch 12/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.3653 - accuracy: 0.0265 - custom_acc: 0.0335
# Epoch 13/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.3351 - accuracy: 0.0262 - custom_acc: 0.0349
# Epoch 14/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.3069 - accuracy: 0.0268 - custom_acc: 0.0339
# Epoch 15/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.3034 - accuracy: 0.0271 - custom_acc: 0.0394
# Epoch 16/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.2653 - accuracy: 0.0271 - custom_acc: 0.0485
# Epoch 17/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.2360 - accuracy: 0.0279 - custom_acc: 0.0493
# Epoch 18/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.2312 - accuracy: 0.0280 - custom_acc: 0.0885
# Epoch 19/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.2137 - accuracy: 0.0285 - custom_acc: 0.2143
# Epoch 20/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1931 - accuracy: 0.0287 - custom_acc: 0.3332
# Epoch 21/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1726 - accuracy: 0.0290 - custom_acc: 0.3830
# Epoch 22/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1750 - accuracy: 0.0293 - custom_acc: 0.4236
# Epoch 23/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1559 - accuracy: 0.0293 - custom_acc: 0.4490
# Epoch 24/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1378 - accuracy: 0.0293 - custom_acc: 0.4752
# Epoch 25/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1186 - accuracy: 0.0296 - custom_acc: 0.4961
# Epoch 26/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1094 - accuracy: 0.0298 - custom_acc: 0.5100
# Epoch 27/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.1043 - accuracy: 0.0296 - custom_acc: 0.5161
# Epoch 28/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0883 - accuracy: 0.0301 - custom_acc: 0.5193
# Epoch 29/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0818 - accuracy: 0.0300 - custom_acc: 0.5210
# Epoch 30/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0794 - accuracy: 0.0301 - custom_acc: 0.5182
# Epoch 31/1000
# 300/300 [==============================] - 26s 85ms/sample - loss: 0.0750 - accuracy: 0.0300 - custom_acc: 0.5192
# Epoch 32/1000
# 300/300 [==============================] - 26s 86ms/sample - loss: 0.0676 - accuracy: 0.0301 - custom_acc: 0.5206
# Epoch 33/1000
# 300/300 [==============================] - 27s 89ms/sample - loss: 0.0613 - accuracy: 0.0303 - custom_acc: 0.5185
# Epoch 34/1000
# 300/300 [==============================] - 26s 86ms/sample - loss: 0.0602 - accuracy: 0.0300 - custom_acc: 0.5186
# Epoch 35/1000
# 300/300 [==============================] - 25s 84ms/sample - loss: 0.0600 - accuracy: 0.0304 - custom_acc: 0.5192
# Epoch 36/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0570 - accuracy: 0.0303 - custom_acc: 0.5193
# Epoch 37/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0530 - accuracy: 0.0300 - custom_acc: 0.5202
# Epoch 38/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0518 - accuracy: 0.0303 - custom_acc: 0.5200
# Epoch 39/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0522 - accuracy: 0.0302 - custom_acc: 0.5195
# Epoch 40/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0538 - accuracy: 0.0302 - custom_acc: 0.5213
# Epoch 41/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0432 - accuracy: 0.0303 - custom_acc: 0.5205
# Epoch 42/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0410 - accuracy: 0.0302 - custom_acc: 0.5218
# Epoch 43/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0403 - accuracy: 0.0301 - custom_acc: 0.5215
# Epoch 44/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0396 - accuracy: 0.0300 - custom_acc: 0.5212
# Epoch 45/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0390 - accuracy: 0.0303 - custom_acc: 0.5234
# Epoch 46/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0385 - accuracy: 0.0300 - custom_acc: 0.5212
# Epoch 47/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0381 - accuracy: 0.0301 - custom_acc: 0.5228
# Epoch 48/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0378 - accuracy: 0.0302 - custom_acc: 0.5219
# Epoch 49/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0375 - accuracy: 0.0300 - custom_acc: 0.5239
# Epoch 50/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0372 - accuracy: 0.0299 - custom_acc: 0.5228
# Epoch 51/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0370 - accuracy: 0.0302 - custom_acc: 0.5202
# Epoch 52/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0368 - accuracy: 0.0299 - custom_acc: 0.5248
# Epoch 53/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0366 - accuracy: 0.0300 - custom_acc: 0.5227
# Epoch 54/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0364 - accuracy: 0.0302 - custom_acc: 0.5229
# Epoch 55/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0363 - accuracy: 0.0301 - custom_acc: 0.5237
# Epoch 56/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0362 - accuracy: 0.0301 - custom_acc: 0.5260
# Epoch 57/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0361 - accuracy: 0.0301 - custom_acc: 0.5226
# Epoch 58/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0360 - accuracy: 0.0300 - custom_acc: 0.5236
# Epoch 59/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0359 - accuracy: 0.0296 - custom_acc: 0.5245
# Epoch 60/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0358 - accuracy: 0.0300 - custom_acc: 0.5226
# Epoch 61/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0358 - accuracy: 0.0301 - custom_acc: 0.5263
# Epoch 62/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0357 - accuracy: 0.0302 - custom_acc: 0.5224
# Epoch 63/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0356 - accuracy: 0.0301 - custom_acc: 0.5258
# Epoch 64/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0356 - accuracy: 0.0301 - custom_acc: 0.5256
# Epoch 65/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0356 - accuracy: 0.0298 - custom_acc: 0.5242
# Epoch 66/1000
# 300/300 [==============================] - 26s 86ms/sample - loss: 0.0356 - accuracy: 0.0300 - custom_acc: 0.5248
# Epoch 67/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0352 - accuracy: 0.0300 - custom_acc: 0.5237
# Epoch 68/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0352 - accuracy: 0.0301 - custom_acc: 0.5243
# Epoch 69/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0352 - accuracy: 0.0301 - custom_acc: 0.5244
# Epoch 70/1000
# 300/300 [==============================] - 25s 84ms/sample - loss: 0.0352 - accuracy: 0.0300 - custom_acc: 0.5267
# Epoch 71/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0350 - accuracy: 0.0300 - custom_acc: 0.5236
# Epoch 72/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0350 - accuracy: 0.0303 - custom_acc: 0.5243
# Epoch 73/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0350 - accuracy: 0.0302 - custom_acc: 0.5253
# Epoch 74/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0350 - accuracy: 0.0301 - custom_acc: 0.5246
# Epoch 75/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0349 - accuracy: 0.0299 - custom_acc: 0.5257
# Epoch 76/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0349 - accuracy: 0.0300 - custom_acc: 0.5247
# Epoch 77/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0349 - accuracy: 0.0300 - custom_acc: 0.5250
# Epoch 78/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0349 - accuracy: 0.0300 - custom_acc: 0.5247
# Epoch 79/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5250
# Epoch 80/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5253
# Epoch 81/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5253
# Epoch 82/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0298 - custom_acc: 0.5255
# Epoch 83/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 84/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5251
# Epoch 85/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0303 - custom_acc: 0.5255
# Epoch 86/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0299 - custom_acc: 0.5254
# Epoch 87/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5253
# Epoch 88/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0299 - custom_acc: 0.5254
# Epoch 89/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0303 - custom_acc: 0.5254
# Epoch 90/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0303 - custom_acc: 0.5253
# Epoch 91/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 92/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 93/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0298 - custom_acc: 0.5253
# Epoch 94/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5254
# Epoch 95/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5254
# Epoch 96/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 97/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5254
# Epoch 98/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 99/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5253
# Epoch 100/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5254
# Epoch 101/1000
# 300/300 [==============================] - 25s 82ms/sample - loss: 0.0348 - accuracy: 0.0299 - custom_acc: 0.5253
# Epoch 102/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0300 - custom_acc: 0.5254
# Epoch 103/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0299 - custom_acc: 0.5254
# Epoch 104/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0304 - custom_acc: 0.5254
# Epoch 105/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5254
# Epoch 106/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0302 - custom_acc: 0.5254
# Epoch 107/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0304 - custom_acc: 0.5253
# Epoch 108/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0299 - custom_acc: 0.5254
# Epoch 109/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0301 - custom_acc: 0.5254
# Epoch 110/1000
# 300/300 [==============================] - 25s 83ms/sample - loss: 0.0348 - accuracy: 0.0303 - custom_acc: 0.5253

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

loss = history.history['loss']
acc = history.history['custom_acc']

epochs = len(loss)
plt.plot(range(epochs), loss, marker='.', label='loss')
plt.plot(range(epochs), acc, marker='.', label='custom_acc')
plt.legend(loc='best')
plt.grid()
plt.title("learning_plot_{}".format(model_num))
plt.xlabel('epoch')
plt.ylabel('loss,acc')
plt.savefig("learning_plot_{}.png".format(model_num))
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

x_test_encoded = encoder.predict(data_train, batch_size=16)
x_test_encoded = np.array(x_test_encoded)
mu = x_test_encoded[0]
sigma = x_test_encoded[1]
z = x_test_encoded[2]

ones = np.ones([50,1])
y_test = np.vstack((ones,ones*2,ones*3,ones*4,ones*5,ones*6))

# %%
# %matplotlib inline
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
#scatter = plt.scatter(x_test_encoded[2,:,0], x_test_encoded[2,:,1], c=y_test, cmap='RdYlBu')
scatter = ax.scatter(np.std(sigma[:,:],axis=-1),
                     np.mean(mu[:,:25],axis=-1),
                     np.mean(mu[:,25:],axis=-1),
                     c=y_test, cmap='RdYlBu', s=10)
ax.set_xlabel("x", size = 14)
ax.set_ylabel("y", size = 14)
ax.set_zlabel("z", size = 14)
fig.colorbar(scatter)
ax.view_init(elev=40, azim=120)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
#scatter = plt.scatter(x_test_encoded[2,:,0], x_test_encoded[2,:,1], c=y_test, cmap='RdYlBu')
scatter = ax.scatter(np.std(mu[:,:15],axis=-1),
                     np.mean(mu[:,15:30],axis=-1),
                     np.std(mu[:,30:],axis=-1),
                     c=y_test, cmap='RdYlBu', s=10)
ax.set_xlabel("x", size = 14)
ax.set_ylabel("y", size = 14)
ax.set_zlabel("z", size = 14)
fig.colorbar(scatter)
ax.set_xlim(0,0.01)
ax.set_ylim(-0.005,0.01)
ax.set_zlim(-0.001,0.05)
ax.view_init(elev=60, azim=20)
plt.show()

# %%
outputs = decoder.predict(z)

outputs[np.where(outputs<=-0.001)]=0
outputs[np.where(outputs<0)]*=-1

outputs[:,0,:,:,:] *= A_max
outputs[:,1,:,:,:] *= B_max
outputs[:,2,:,:,:] *= C_max
#outputs[:,3,:,:,:] *= W_max

np.save('volume_fraction/outputs_{}'.format(model_num), outputs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-2fbde65cecf0> in <module>
#       6 outputs[:,0,:,:,:] *= A_max
#       7 outputs[:,1,:,:,:] *= B_max
# ----> 8 outputs[:,2,:,:,:] *= C_max
#       9 #outputs[:,3,:,:,:] *= W_max
#      10
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
np.max(outputs)

# %%
import pandas as pd
df = pd.DataFrame(outputs[0,1,20,:,:].reshape(-1,1))
df.describe()

# %%
z_sample = np.random.normal(loc=0.1, scale=0.8, size=(1,10))

x_decoded = decoder.predict(z_sample)

np.save('volume_fraction/x_decoded_{}'.format(model_num), x_decoded)
