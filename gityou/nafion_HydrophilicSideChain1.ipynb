# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
data_name = 'HydrophilicSideChain1/nafion_out_HydrophilicSideChain1_{}.csv'
data_num = np.arange(0,101,10)
data_num = np.append(data_num, 101)
data_num
data = [[],[],[],[],[],[],[],[],[],[],[],[]]
for i,j in enumerate(data_num):
    data[i] = pd.read_csv(data_name.format(j),index_col=0,names=['X','Y','Z'])

# %%
data[11].describe()
# Out:
#                    X              Y              Z
# count  192000.000000  192000.000000  192000.000000
# mean       19.685797      20.133312      19.879690
# std        42.351041      42.537598      43.355196
# min      -303.650000    -313.283000    -305.229000
# 25%        -4.404500      -4.363000      -5.345250
# 50%        19.781000      19.916500      19.658500
# 75%        43.884250      44.741250      45.324250
# max       342.643000     310.528000     321.464000

# %%
a = data[11].loc['A']
a.describe()
# Out:
#                    X              Y              Z
# count  102400.000000  102400.000000  102400.000000
# mean       19.417669      19.916207      19.724400
# std        29.273386      29.636933      30.765308
# min       -78.212000     -66.046000     -76.400000
# 25%        -1.641000      -1.524250      -2.590750
# 50%        19.716000      19.798000      19.576500
# 75%        40.668250      41.619250      42.451250
# max       117.153000     123.729000     115.758000

# %%
b = data[0].loc['B']
b.describe()
# Out:
#                   X             Y             Z
# count  25600.000000  25600.000000  25600.000000
# mean      19.599655     20.190465     19.860517
# std       23.147298     23.017090     23.292859
# min      -25.471000    -25.010000    -25.252000
# 25%       -0.591500      0.429500     -0.783750
# 50%       19.628000     19.875500     20.286500
# 75%       39.654500     40.064250     39.932250
# max       63.865000     65.751000     63.738000

# %%
c = data[0].loc['C']
c.describe()
# Out:
#                   X             Y             Z
# count  25600.000000  25600.000000  25600.000000
# mean      19.601079     20.190476     19.855249
# std       23.150025     23.025443     23.298790
# min      -25.317000    -25.509000    -26.100000
# 25%       -0.527000      0.412000     -0.833250
# 50%       19.615000     19.965500     20.288500
# 75%       39.615750     40.052500     39.915000
# max       64.674000     66.163000     63.718000

# %%
w = data[0].loc['W']
w.describe()
# Out:
#                   X             Y             Z
# count  38400.000000  38400.000000  38400.000000
# mean      20.031080     19.921032     19.954575
# std       23.122736     23.121139     23.111869
# min      -19.997000    -20.000000    -19.996000
# 25%        0.023250      0.069250     -0.088500
# 50%       19.929000     19.596500     19.873000
# 75%       40.161500     39.928250     39.976250
# max       59.996000     59.999000     59.997000

# %%
# %matplotlib notebook
#データをarray型に
x1,y1,z1 = np.array(a["X"]),np.array(a["Y"]),np.array(a["Z"])
x2,y2,z2 = np.array(b["X"]),np.array(b["Y"]),np.array(b["Z"])
x3,y3,z3 = np.array(c["X"]),np.array(c["Y"]),np.array(c["Z"])
x4,y4,z4 = np.array(w["X"]),np.array(w["Y"]),np.array(w["Z"])

# グラフ作成
fig = plt.figure()
ax = Axes3D(fig)

#ax.scatter(x1, y1, z1,s=0.1)
#ax.scatter(x2, y2, z2,s=0.1)
ax.scatter(x3, y3, z3,s=0.1)
#ax.scatter(x4, y4, z4,s=0.1)
# 軸ラベルの設定
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
